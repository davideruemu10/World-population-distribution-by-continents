# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#load the dataset
df=pd.read_csv('world_population.csv')
df.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia         41128771
# 1   138  ALB         Albania            Tirana    Europe          2842321
# 2    34  DZA         Algeria           Algiers    Africa         44903225
# 3   213  ASM  American Samoa         Pago Pago   Oceania            44273
# 4   203  AND         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
#inspect the structure of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df.Country.duplicated().any()
# Out:
# False

# %%
df.Continent.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Oceania', 'North America',
#        'South America'], dtype=object)

# %%
#get some basic statistical information on the dataset
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %%
#Create a new dataframe grouping the countries by continent
df2=df.groupby("Continent")[["Area (km²)","2022 Population",'1970 Population',"World Population Percentage"]].sum()

# %%
#Calculate the total area 
total_area=df2["Area (km²)"].sum()

# %%
#Calculate the Percentage of the world's area occupied by each continent
df2["World Area Percentage"]=df2["Area (km²)"]/total_area*100

# %%
#Calculate the Population density of each country
df2["Density (per km²)"]=df2["2022 Population"]/df2["Area (km²)"]

# %%
df2=df2.reset_index()
df2
# Out:
#        Continent  Area (km²)  2022 Population  1970 Population  \
# 0         Africa    30317963       1426730932        365444348
# 1           Asia    32138141       4721383274       2144906290
# 2         Europe    23010411        743147538        655923991
# 3  North America    24244178        600296136        315434606
# 4        Oceania     8515081         45038554         19480270
# 5  South America    17833382        436816608        192947156
#
#    World Population Percentage  World Area Percentage  Density (per km²)
# 0                        17.87              22.282927          47.058931
# 1                        59.19              23.620712         146.909035
# 2                         9.33              16.912064          32.296144
# 3                         7.51              17.818851          24.760424
# 4                         0.55               6.258367           5.289269
# 5                         5.48              13.107080          24.494322

# %%
plt.figure(figsize=(10,30))
plt.subplot(1,2,1)
plt.pie(df2['World Area Percentage'], labels = df2['Continent'])
plt.title("Land Area taken up by each continent");

plt.subplot(1,2,2)
plt.pie(df2['World Population Percentage'], labels = df2['Continent'])
plt.title("Percentage of the population of each continent");

# %%
import numpy as np
populationcnt = ["0",'1billion','2billion','3billion','4billion','5billion']
plt.figure(figsize=(10,10))
X_axis = np.arange(len(df2))
plt.bar(X_axis - 0.2, df2["2022 Population"], 0.4, label = '2022')
plt.bar(X_axis + 0.2, df2["1970 Population"], 0.4, label = '1970')
plt.xticks(X_axis,list(df2["Continent"]),rotation=45)
plt.yticks(np.arange(0,5000000001,1000000000),populationcnt)
plt.legend();
